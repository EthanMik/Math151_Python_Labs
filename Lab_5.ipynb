# %% [markdown]
# ## MATH 151 Lab  5

# %% [markdown]
# Put team members' names and section number here.

# %%
import sympy as sp
from sympy import *
from sympy.plotting import (plot,plot_parametric,plot_implicit)
x, y, C = sp.symbols('x y C', real = True)

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
curve = (x - 1) * (y - 1)

plot_implicit(curve, (x, -5, 5), (y, -5, 5))

# %% [markdown]
# #### 1b

# %%
dcurve = idiff(curve, y, x)
display(dcurve)

# Singularity at x = -1
# Out:
# (1 - y)/(x - 1)

# %% [markdown]
# #### 1c

# %%
curve = x*x + y*y - 1

plot_implicit(curve, (x, -5, 5), (y, -5, 5))

display(idiff(curve, y, x))

# Singularity y = 0
# Out:
# -x/y

# %% [markdown]
# 1d

# %%
A, B = symbols("A B", real=True)

point1 = 27 * B**2
point2 = 4 * A**3

display(solve(point1 - 2, B))
display(solve(point2 - -3, A))

ellip_curve = x**3 - 3*x + 2 - y**2

plot_implicit(ellip_curve, (x, -5, 5), (y, -5, 5))
# Out:
# [-sqrt(6)/9, sqrt(6)/9]
# [-6**(1/3)/2]

# %% [markdown]
# 1e

# %%
dellip_curve = idiff(ellip_curve, y, x)
display(dellip_curve)
num = 3 * (x**2 - 1)

htan = solve(num, x)
print(f"dy/dx = 0 at x = {htan}")
# Out:
# 3*(x**2 - 1)/(2*y)
# dy/dx = 0 at x = [-1, 1]

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
# Enter your code here

# %% [markdown]
# #### 2b

# %%
# Enter your code here

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
x, y = symbols("x, y", real=True)
a, c = symbols("a, c", real=True)

f = (x**2 + y**2 + a**2)**2 - (4 * a**2 * x**2) - c**4

dydx = idiff(f, y, x)

display(dydx)
# Out:
# x*(a**2/y - x**2/y - y)/(a**2 + x**2 + y**2)

# %% [markdown]
# #### 3b

# %%
d2ydx = idiff(dydx.subs(a, 1), y, x)

display(d2ydx)
# Out:
# y*(x**3 + 2*x*y**2 + 4*x + y**4/x - 1/x)/(x**4 + 2*x**2*y**2 + y**4 - 4*y**2 - 1)

# %% [markdown]
# #### 3c

# %%
f = f.subs({a: 1, c:2})

num = x * ((-x**2 / y) - y + (1 / y))
den = x*x + y*y + 1

htan = solve([num, f], [x, y])
print(f"Horizontal tangents at {htan}")

vtan = solve([den, f], [x, y])
print(f"Vertical tangent at {vtan}")
# Out:
# Horizontal tangents at [(0, -sqrt(3)), (0, sqrt(3))]
# Vertical tangent at []
