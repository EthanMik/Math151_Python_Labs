# %% [markdown]
# ## MATH 151 Lab 8

# %% [markdown]
# Put team members' names and section number here.

# %%
import sympy as sp
from sympy import *
from sympy.plotting import (plot,plot_parametric)

x, y, t, b = symbols("x y t b", real=True)

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
# Enter your code here

# %% [markdown]
# #### 1b

# %%
# Enter your code here

# %% [markdown]
# #### 1c

# %%
# Enter your answer here

# %% [markdown]
# #### 1d

# %%
# Enter your code here

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
f = x
g = x + 1 

limit(f/g, x, 1) == limit(diff(f, x)/diff(g, x), x, 1)
# Out:
# False

# %% [markdown]
# #### 2b

# %%
def intersect(f):
    return solve(f - diff(f), x)

solutions = intersect(x**2 + 1)
display(solutions)
# Out:
# [1]

# %% [markdown]
# #### 2c

# %%
L = x + b

dL = diff(L, x)
L = L.subs(b, solve(L - 1, b)[0])

L == dL
# Out:
# True

# %% [markdown]
# #### 2d

# %%
f = x ** 2 + 1
g = x

limit(f / g, x, 1) == limit(diff(f, x) / diff(g, x), x, 1)
# Out:
# True

# %% [markdown]
# ####2e

# %%
f = sin(x)
g = x

limit(f / g, x, 1) == limit(diff(f, x) / diff(g, x), x, 1)
# Out:
# False

# %% [markdown]
# ####2f

# %%
f = sin(x)
g = x

fg = f / g
dfg = diff(f, x) / diff(g, x)
